# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
farr = loaded_ds = np.load('faces.npy')
print(farr.shape)
# Out:
# (2000, 112, 112, 3)

# %%
nb = 25
offset = 100
#fig, axs = plt.subplots(nb/4, 4, figsize=(5, 5))
plt.figure(figsize=(20,15))
#plt. subplots(2,4,figsize=(10,10))
for i in range(nb):
    plt.subplot(nb/5, 5, i+1)
    #plt.xlim(0, 200)
    #plt.ylim(200, 0)
    plt.axis('off')
    plt.title(i+offset)
    plt.imshow(farr[i+offset])
# Out:
# <ipython-input-55-dd5f6cc86cdb>:7: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(nb/5, 5, i+1)
